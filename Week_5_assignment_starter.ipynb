# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %%
#Load packages
import pandas as pd

#Load data
df = pd.read_csv('prepped_churn_data.csv')
df.head(3)
# Out:
#    customerID  tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0        5365       1             0         0              0           29.85
# 1        3953      34             1         1              1           56.95
# 2        2558       2             1         0              1           53.85
#
#    TotalCharges  Churn  MonthlyC_TotalC_ratio  TotalC_tenure_ratio
# 0         29.85      0                1.00000            29.850000
# 1       1889.50      0                0.03014            55.573529
# 2        108.15      1                0.49792            54.075000

# %%
#Data Preparation
#AutoML with pycaret 
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %%
# ?setup

# %%
#setup function

#preprocess = False
#ignore_features = ['customerID']

automl = setup(df, target='Churn')
# Out:
# <style  type="text/css" >
# </style><table id="T_35bd7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_35bd7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_35bd7_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_35bd7_row0_col1" class="data row0 col1" >3796</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_35bd7_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_35bd7_row1_col1" class="data row1 col1" >Churn</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_35bd7_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_35bd7_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_35bd7_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_35bd7_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_35bd7_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_35bd7_row4_col1" class="data row4 col1" >(7032, 10)</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_35bd7_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_35bd7_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_35bd7_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_35bd7_row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_35bd7_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_35bd7_row7_col1" class="data row7 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_35bd7_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_35bd7_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_35bd7_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_35bd7_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_35bd7_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_35bd7_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_35bd7_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_35bd7_row11_col1" class="data row11 col1" >(4922, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_35bd7_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_35bd7_row12_col1" class="data row12 col1" >(2110, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_35bd7_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_35bd7_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_35bd7_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_35bd7_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_35bd7_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_35bd7_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_35bd7_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_35bd7_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_35bd7_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_35bd7_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_35bd7_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_35bd7_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_35bd7_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_35bd7_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_35bd7_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_35bd7_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_35bd7_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_35bd7_row21_col1" class="data row21 col1" >4919</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_35bd7_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_35bd7_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_35bd7_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_35bd7_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_35bd7_level0_row24" class="row_heading level0 row24" >24</th>
#                         <td id="T_35bd7_row24_col0" class="data row2

# %% [markdown]
# - #11 Transformed Train Set	(n, 12)
# - #12 Transformed Test Set	(n, 12)

# %%
#setup function

#preprocess = False
#(n, 8)
automl = setup(df, target='Churn', preprocess = False)
# Out:
# <style  type="text/css" >
# </style><table id="T_d728e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d728e_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d728e_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d728e_row0_col1" class="data row0 col1" >4487</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d728e_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_d728e_row1_col1" class="data row1 col1" >Churn</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d728e_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_d728e_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d728e_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_d728e_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d728e_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_d728e_row4_col1" class="data row4 col1" >(7032, 10)</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d728e_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_d728e_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d728e_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_d728e_row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d728e_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_d728e_row7_col1" class="data row7 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d728e_row8_col0" class="data row8 col0" >Transformed Train Set</td>
#                         <td id="T_d728e_row8_col1" class="data row8 col1" >(4922, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_d728e_row9_col0" class="data row9 col0" >Transformed Test Set</td>
#                         <td id="T_d728e_row9_col1" class="data row9 col1" >(2110, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_d728e_row10_col0" class="data row10 col0" >Shuffle Train-Test</td>
#                         <td id="T_d728e_row10_col1" class="data row10 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_d728e_row11_col0" class="data row11 col0" >Stratify Train-Test</td>
#                         <td id="T_d728e_row11_col1" class="data row11 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_d728e_row12_col0" class="data row12 col0" >Fold Generator</td>
#                         <td id="T_d728e_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_d728e_row13_col0" class="data row13 col0" >Fold Number</td>
#                         <td id="T_d728e_row13_col1" class="data row13 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_d728e_row14_col0" class="data row14 col0" >CPU Jobs</td>
#                         <td id="T_d728e_row14_col1" class="data row14 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_d728e_row15_col0" class="data row15 col0" >Use GPU</td>
#                         <td id="T_d728e_row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_d728e_row16_col0" class="data row16 col0" >Log Experiment</td>
#                         <td id="T_d728e_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_d728e_row17_col0" class="data row17 col0" >Experiment Name</td>
#                         <td id="T_d728e_row17_col1" class="data row17 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_d728e_row18_col0" class="data row18 col0" >USI</td>
#                         <td id="T_d728e_row18_col1" class="data row18 col1" >0e62</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_d728e_row19_col0" class="data row19 col0" >Fix Imbalance</td>
#                         <td id="T_d728e_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d728e_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_d728e_row20_col0" class="data row20 col0" >Fix Imbalance Method</td>
#                         <td id="T_d728e_row20_col1" class="data row20 col1" >SMOTE</td>
#             </tr>
#     </tbody></table>

# %%
#automl[6]
#automl[14]

# %%
#sklearn using autoML to find best model 
best_model = compare_models(sort='Accuracy')
# Out:
# <style  type="text/css" >
#     #T_1cf31_ th {
#           text-align: left;
#     }#T_1cf31_row0_col0,#T_1cf31_row0_col2,#T_1cf31_row0_col3,#T_1cf31_row0_col4,#T_1cf31_row0_col5,#T_1cf31_row0_col7,#T_1cf31_row1_col0,#T_1cf31_row1_col1,#T_1cf31_row1_col2,#T_1cf31_row1_col3,#T_1cf31_row1_col4,#T_1cf31_row1_col5,#T_1cf31_row1_col6,#T_1cf31_row1_col7,#T_1cf31_row2_col0,#T_1cf31_row2_col1,#T_1cf31_row2_col2,#T_1cf31_row2_col3,#T_1cf31_row2_col5,#T_1cf31_row2_col6,#T_1cf31_row2_col7,#T_1cf31_row3_col0,#T_1cf31_row3_col1,#T_1cf31_row3_col2,#T_1cf31_row3_col3,#T_1cf31_row3_col4,#T_1cf31_row3_col5,#T_1cf31_row3_col6,#T_1cf31_row3_col7,#T_1cf31_row4_col0,#T_1cf31_row4_col1,#T_1cf31_row4_col3,#T_1cf31_row4_col4,#T_1cf31_row4_col5,#T_1cf31_row4_col6,#T_1cf31_row4_col7,#T_1cf31_row5_col0,#T_1cf31_row5_col1,#T_1cf31_row5_col2,#T_1cf31_row5_col3,#T_1cf31_row5_col4,#T_1cf31_row5_col5,#T_1cf31_row5_col6,#T_1cf31_row5_col7,#T_1cf31_row6_col0,#T_1cf31_row6_col1,#T_1cf31_row6_col2,#T_1cf31_row6_col3,#T_1cf31_row6_col4,#T_1cf31_row6_col5,#T_1cf31_row6_col6,#T_1cf31_row6_col7,#T_1cf31_row7_col0,#T_1cf31_row7_col1,#T_1cf31_row7_col2,#T_1cf31_row7_col3,#T_1cf31_row7_col4,#T_1cf31_row7_col5,#T_1cf31_row7_col6,#T_1cf31_row7_col7,#T_1cf31_row8_col0,#T_1cf31_row8_col1,#T_1cf31_row8_col2,#T_1cf31_row8_col3,#T_1cf31_row8_col4,#T_1cf31_row8_col5,#T_1cf31_row8_col6,#T_1cf31_row8_col7,#T_1cf31_row9_col0,#T_1cf31_row9_col1,#T_1cf31_row9_col2,#T_1cf31_row9_col3,#T_1cf31_row9_col4,#T_1cf31_row9_
row2_col2" class="data row2 col2" >0.0000</td>
#                         <td id="T_1cf31_row2_col3" class="data row2 col3" >0.4169</td>
#                         <td id="T_1cf31_row2_col4" class="data row2 col4" >0.6688</td>
#                         <td id="T_1cf31_row2_col5" class="data row2 col5" >0.5123</td>
#                         <td id="T_1cf31_row2_col6" class="data row2 col6" >0.3882</td>
#                         <td id="T_1cf31_row2_col7" class="data row2 col7" >0.4064</td>
#                         <td id="T_1cf31_row2_col8" class="data row2 col8" >0.0100</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf31_level0_row3" class="row_heading level0 row3" >lda</th>
#                         <td id="T_1cf31_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#                         <td id="T_1cf31_row3_col1" class="data row3 col1" >0.7899</td>
#                         <td id="T_1cf31_row3_col2" class="data row3 col2" >0.8289</td>
#                         <td id="T_1cf31_row3_col3" class="data row3 col3" >0.4706</td>
#                         <td id="T_1cf31_row3_col4" class="data row3 col4" >0.6424</td>
#                         <td id="T_1cf31_row3_col5" class="data row3 col5" >0.5423</td>
#                         <td id="T_1cf31_row3_col6" class="data row3 col6" >0.4104</td>
#                         <td id="T_1cf31_row3_col7" class="data row3 col7" >0.4193</td>
#                         <td id="T_1cf31_row3_col8" class="data row3 col8" >0.0120</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf31_level0_row4" class="row_heading level0 row4" >lr</th>
#                         <td id="T_1cf31_row4_col0" class="data row4 col0" >Logistic Regression</td>
#                         <td id="T_1cf31_row4_col1" class="data row4 col1" >0.7891</td>
#                         <td id="T_1cf31_row4_col2" class="data row4 col2" >0.8338</td>
#                         <td id="T_1cf31_row4_col3" class="data row4 col3" >0.4936</td>
#                         <td id="T_1cf31_row4_col4" class="data row4 col4" >0.6327</td>
#                         <td id="T_1cf31_row4_col5" class="data row4 col5" >0.5536</td>
#                         <td id="T_1cf31_row4_col6" class="data

# %%
#viewing best model
best_model

# %% [markdown]
# Best Model is CatBoost Xlassiferier followed by gbc and ridge. Accuracy range is close together with majority of models.

# %%
df.iloc[-2:-1].shape
# Out:
# (1, 10)

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
#       customerID  tenure  PhoneService  Contract  PaymentMethod  \
# 7030        5923       4             1         0              1
#
#       MonthlyCharges  TotalCharges  Churn  MonthlyC_TotalC_ratio  \
# 7030            74.4         306.6      1               0.242661
#
#       TotalC_tenure_ratio  Label   Score
# 7030                76.65      1  0.5673

# %% [markdown]
# # Saving and loading the best model

# %%
#Saving best model
save_model(best_model, 'catboost')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=['customerID'],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Churn',
#                                        time_features=[])),
#                  ['trained_model',
#                   <catboost.core.CatBoostClassifier object at 0x138ce4610>]],
#           verbose=False),
#  'catboost.pkl')

# %%
import pickle
with open('catboost_model.pk', 'wb') as f:        #Write binary 
    pickle.dump(best_model, f)

# %%
#Read binary 

with open('catboost_model.pk', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
df.iloc[-1].shape
# Out:
# (10,)

# %%
new_data = df.iloc[-2:-1].copy()
new_data.drop('Churn', axis=1, inplace=True)
loaded_model.predict(new_data)
# Out:
# array([1])

# %%
loaded_catboost = load_model('catboost')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
predict_model(loaded_catboost, new_data)
# Out:
#       customerID  tenure  PhoneService  Contract  PaymentMethod  \
# 7030        5923       4             1         0              1
#
#       MonthlyCharges  TotalCharges  MonthlyC_TotalC_ratio  \
# 7030            74.4         306.6               0.242661
#
#       TotalC_tenure_ratio  Label   Score
# 7030                76.65      1  0.5673

# %% [markdown]
# # Making a Python module to make predictions

# %%
from IPython.display import Code

Code('predict_churn.py')
# Out:
# import pandas as pd
# from pycaret.classification import predict_model, load_model
#
# def load_data(filepath):
#     """
#     Loads prepped churn data into a DataFrame from a string filepath.
#     """
#     df = pd.read_csv(filepath)
#     return df
#
#
# def make_predictions(df):
#     """
#     Uses the pycaret best model to make predictions on data in the df dataframe.
#     """
#     model = load_model('catboost')
#     predictions = predict_model(model, data=df)
#     predictions.rename({'Label': 'Churn_prediction'}, axis=1, inplace=True)
#     predictions['Churn_prediction'].replace({1: 'Churn', 0: 'No Churn'},
#                                             inplace=True)
#     return predictions['Churn_prediction']
#
#
# if __name__ == "__main__":
#     df = load_data('prepped_churn_data.csv')
#     predictions = make_predictions(df)
#     print('predictions:')
#     print(predictions)

# %%
# %run predict_churn.py
# Out:
# Transformation Pipeline and Model Successfully Loaded
# predictions:
# 0          Churn
# 1       No Churn
# 2       No Churn
# 3       No Churn
# 4          Churn
#           ...
# 7027    No Churn
# 7028    No Churn
# 7029    No Churn
# 7030       Churn
# 7031    No Churn
# Name: Churn_prediction, Length: 7032, dtype: object

# %%
#Saved to Github

# %% [markdown]
# # Summary

# %% [markdown]
# Write a short summary of the process and results here.
